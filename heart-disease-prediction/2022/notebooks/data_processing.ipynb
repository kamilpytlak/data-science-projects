# %% [markdown]
# # Loading libraries, setting constants

# %%
from pathlib import Path

import pandas as pd

# %%
DATA_PATH = Path('../data')
RAW_DATA_PATH = DATA_PATH / 'raw'
PROCESSED_DATA_PATH = DATA_PATH / 'processed'

RAW_FILE_PATH = RAW_DATA_PATH / 'LLCP2022.XPT'
PROCESSED_FILE_PATH_PARQUET = PROCESSED_DATA_PATH / 'heart_converted.parquet'

# %% [markdown]
# ## Converting SAS to PARQUET

# %%
def sas_converter(path: str, dest_path: str, file_format: str):
    assert file_format in ['csv', 'parquet']
    
    try:
        df = pd.read_sas(path, encoding='utf-8')
    except Exception as e:
        print('Not a valid SAS file.')
    else:
        if file_format == 'csv':
            df.to_csv(dest_path, index=False)
        elif file_format == 'parquet':
            df.to_parquet(dest_path, index=False)

# %%
sas_converter(path=RAW_FILE_PATH, dest_path=PROCESSED_FILE_PATH_PARQUET, file_format='parquet')
# Out:
# C:\Users\kampy\AppData\Local\Temp\ipykernel_31888\2950354527.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df = pd.read_sas(path, encoding='utf-8')
# C:\Users\kampy\AppData\Local\Temp\ipykernel_31888\2950354527.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df = pd.read_sas(path, encoding='utf-8')
# ...

# %% [markdown]
# # Data preprocessing

# %%
heart_2021 = pd.read_parquet(PROCESSED_FILE_PATH_PARQUET)

# %%
heart_2021['CVDINFR4']
# Out:
# 0         2.0
# 1         2.0
# 2         2.0
# 3         2.0
# 4         2.0
#          ...
# 445127    2.0
# 445128    2.0
# 445129    2.0
# 445130    1.0
# 445131    2.0
# Name: CVDINFR4, Length: 445132, dtype: float64

# %%
used_columns = ['_STATE', 'SEXVAR', 'GENHLTH', 'PHYSHLTH', 'MENTHLTH', 'PRIMINSR', 'PERSDOC3', 'MEDCOST1',
                'CHECKUP1', 'EXERANY2', 'BPHIGH6', 'CHOLCHK3', 'TOLDHI3', 'CVDINFR4', 'CVDCRHD4', 'CVDSTRK3',
                'ASTHMA3', 'CHCSCNCR', 'CHCOCNCR', 'CHCCOPD3', 'ADDEPEV3', 'CHCKDNY2', 'DIABETE4', 'HAVARTH5',
                'MARITAL', 'EDUCA', 'RENTHOM1', 'CPDEMO1B', 'VETERAN3', 'EMPLOY1', 'CHILDREN', 'INCOME3', 'WEIGHT2',
                'HEIGHT3', 'DEAF', 'BLIND']
